# %%
from nipype.interfaces import fsl

# %%
applier = fsl.ApplyXfm()

applier.inputs.in_file = '/home/gdholla1/data/standard_masks/young_pag_merge_mean.nii.gz'
applier.inputs.in_matrix_file = '/usr/share/fsl/5.0/etc/flirtsch/ident.mat'
applier.inputs.reference = '/home/gdholla1/data/MNI_2mm.nii.gz'
applier.inputs.out_file = '/home/gdholla1/data/standard_masks/resampled_atag_masks/PAG.nii.gz'
r = applier.run()

# %%
r.outputs
# Out:
# out_file = /home/gdholla1/notebooks/2016_daphne/young_pag_merge_mean_flirt.nii.gz
# out_log = /home/gdholla1/notebooks/2016_daphne/young_pag_merge_mean_flirt.log
# out_matrix_file = /home/gdholla1/notebooks/2016_daphne/young_pag_merge_mean_flirt.mat

# %%
plt.plot(np.loadtxt('/home/gdholla1/data/daphne/mni_masks/extracted_signal/_subject_id_S00/_mask_GPe_L/_extract_weighted_phys0/run1_maths_maths_maths_dtype_mcf_mask_gms_tempfilt_regfilt_maths_weighted.txt'))
plt.plot(np.loadtxt('/home/gdholla1/data/daphne/mni_masks/extracted_signal/_subject_id_S00/_mask_GPe_R/_extract_weighted_phys0/run1_maths_maths_maths_dtype_mcf_mask_gms_tempfilt_regfilt_maths_weighted.txt'))
plt.plot(np.loadtxt('/home/gdholla1/data/daphne/mni_masks/extracted_signal/_subject_id_S00/_mask_GPi_R/_extract_weighted_phys0/run1_maths_maths_maths_dtype_mcf_mask_gms_tempfilt_regfilt_maths_weighted.txt'))
